# %% [markdown]
# # Welcome to the qBraid Course Example
#
# This course demonstrates how to organize notebooks and images for the qBraid platform using the `upload-course-action`.
#
# ## Course Content
# 1. **Introduction**: Overview of the course and environment.
# 2. **QAOA Algorithm**: A deep dive into the Quantum Approximate Optimization Algorithm.
#
# ## Sample Visualizations
# Here are some images generated during the preparation of this course:
#
# ### Satellite Maps
# ![Nakhon Ratchasima](images/n.png)
# ![Khao Yai](images/ky.png)
#
# ### Geography of Thailand
# ![Thailand Bangkok](images/thailand_bangkok.png)
#
# ### Geometry and Graphs
# ![Polygon](images/polygon.png)
# ![Graph](images/graph.png)
